# %% [markdown]
# ## Polynomial regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x=[[6],[8],[10],[14],[18]]
y=[[7],[9],[13],[17.5], [18]]
plt.figure(figsize=(10,6))
plt.scatter(x, y)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
# 2차 다항식, quadratic regression으로 fitting 
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly=poly_features.fit_transform(x)
# 그 후에 linear regression으로 fitting
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
print(lin_reg.intercept_)
print(lin_reg.coef_)
# Out:
# [-8.39765458]
# [[ 2.95615672 -0.08202292]]

# %%
##### 연습: 이때의 MSE 를 구해보자 #######
from sklearn.metrics import mean_squared_error


#---------------------------#
# Out:
# 0.5973912726367886

# %%
# fitting 결과 
plt.scatter(x, y)
xx=np.linspace(0,26, 100)
xx_quadratic=poly_features.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, lin_reg.predict(xx_quadratic), c='r', linestyle='--')
plt.show()

# %%
##### 연습: 3차 다항식으로 fitting해 보자 ######
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# 3차 다항식 cubic regression으로 fitting
poly_features = 

#---------------------------#
# 그 후에 linear regression으로 fitting
lin_reg =

#---------------------------#
# fitting 결과 3차 다항식 계수 출력


#---------------------------#
# Out:
# [6.51033835]
# [[-1.42626096  0.31320489 -0.01103344]]

# %%
# 3차 다항식 fitting 결과 
plt.scatter(x, y)
xx=np.linspace(0,26, 100)
xx_quadratic=poly_features.transform(xx.reshape(xx.shape[0], 1))
plt.plot(xx, lin_reg.predict(xx_quadratic), c='r', linestyle='--')

# %% [markdown]
# ## Overfitting problem

# %%
# 앞의 예에서 degree 올려봄
